# %%
def calculate_cost(board):
    conflicts = 0c
    n = len(board)
    for i in range(n):
        for j in range(i + 1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == j - i:
                conflicts += 1
    return conflicts

def generate_neighbors_by_swapping(board):
    neighbors = []
    n = len(board)
    # Generate neighbors by swapping queens in columns i and j (i < j)
    for i in range(n - 1):
        for j in range(i + 1, n):
            new_board = board[:]
            # Swap positions of queens in columns i and j
            new_board[i], new_board[j] = new_board[j], new_board[i]
            neighbors.append((new_board, (i, j)))  # Store neighbor and swapped columns for tie-break
    return neighbors

def hill_climbing_swap(n, initial_board):
    current_board = initial_board
    current_cost = calculate_cost(current_board)

    print("Initial Board:", current_board)
    print("Initial Cost:", current_cost)

    while current_cost > 0:
        neighbors = generate_neighbors_by_swapping(current_board)
       
        # Find best neighbor(s) with minimum cost
        best_cost = current_cost
        best_neighbors = []
        for neighbor, swapped_pair in neighbors:
            cost = calculate_cost(neighbor)
            print(f"Neighbor: {neighbor}, swapped columns: {swapped_pair}, Cost: {cost}")
            if cost < best_cost:
                best_cost = cost
                best_neighbors = [(neighbor, swapped_pair)]
            elif cost == best_cost:
                best_neighbors.append((neighbor, swapped_pair))
       
        if best_cost >= current_cost:
            print("No better neighbor found. Stuck at local maximum.")
            break
       
        # Tie-breaking: choose neighbor with smallest first swapped column
        best_neighbors.sort(key=lambda x: x[1][0])  # Sort by first swapped column (smallest i)
        current_board, swapped_pair = best_neighbors[0]
        current_cost = best_cost
        print(f"Move to neighbor: {current_board} by swapping columns {swapped_pair}, New Cost: {current_cost}")

    if current_cost == 0:
        print("Goal reached! Solution found:", current_board)
    else:
        print("No solution found.")

# Initial state as per your input
initial_state = [3,1, 2, 0]
hill_climbing_swap(4, initial_state)
# Out:
# Initial Board: [3, 1, 2, 0]
# Initial Cost: 2
# Neighbor: [1, 3, 2, 0], swapped columns: (0, 1), Cost: 1
# Neighbor: [2, 1, 3, 0], swapped columns: (0, 2), Cost: 1
# Neighbor: [0, 1, 2, 3], swapped columns: (0, 3), Cost: 6
# Neighbor: [3, 2, 1, 0], swapped columns: (1, 2), Cost: 6
# Neighbor: [3, 0, 2, 1], swapped columns: (1, 3), Cost: 1
# Neighbor: [3, 1, 0, 2], swapped columns: (2, 3), Cost: 1
# Move to neighbor: [1, 3, 2, 0] by swapping columns (0, 1), New Cost: 1
# Neighbor: [3, 1, 2, 0], swapped columns: (0, 1), Cost: 2
# Neighbor: [2, 3, 1, 0], swapped columns: (0, 2), Cost: 2
# Neighbor: [0, 3, 2, 1], swapped columns: (0, 3), Cost: 4
# Neighbor: [1, 2, 3, 0], swapped columns: (1, 2), Cost: 4
# Neighbor: [1, 0, 2, 3], swapped columns: (1, 3), Cost: 2
# Neighbor: [1, 3, 0, 2], swapped columns: (2, 3), Cost: 0
# Move to neighbor: [1, 3, 0, 2] by swapping columns (2, 3), New Cost: 0
# Goal reached! Solution found: [1, 3, 0, 2]

# %%
 import random
import math

def calculate_cost(board):
    """
    Calculate the number of attacking queen pairs.
    """
    conflicts = 0
    n = len(board)
    for i in range(n):
        for j in range(i + 1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == abs(j - i):
                conflicts += 1
    return conflicts

def generate_random_neighbor(board):
    """
    Generate a neighbor by moving a queen in a random column
    to a random row (different from current).
    """
    n = len(board)
    col = random.randint(0, n - 1)
    row_choices = [r for r in range(n) if r != board[col]]
    new_row = random.choice(row_choices)
    
    neighbor = board[:]
    neighbor[col] = new_row
    return neighbor, col, new_row

def simulated_annealing(n, initial_board, initial_temp=30, alpha=0.95, min_temp=0.01, max_steps=1000):
    current_board = initial_board
    current_cost = calculate_cost(current_board)
    temperature = initial_temp
    step = 0

    print("Initial Board:", current_board, "Cost:", current_cost)
    
    while current_cost > 0 and temperature > min_temp and step < max_steps:
        neighbor, col, row = generate_random_neighbor(current_board)
        neighbor_cost = calculate_cost(neighbor)
        delta = neighbor_cost - current_cost

        print(f"\nStep {step}:")
        print(f"Current Board: {current_board}, Cost: {current_cost}")
        print(f"Neighbor Board: {neighbor}, Cost: {neighbor_cost}, changed col {col} to row {row}")

        # Acceptance probability
        if delta < 0:
            # Better move → accept
            accept = True
        else:
            # Worse move → accept with probability
            accept_prob = math.exp(-delta / temperature)
            accept = random.random() < accept_prob
        
        if accept:
            current_board = neighbor
            current_cost = neighbor_cost
            print(f"Move accepted. New board: {current_board}, Cost: {current_cost}")
        else:
            print("Move rejected.")

        temperature *= alpha  # Cool down
        step += 1

    if current_cost == 0:
        print("\n✅ Goal reached! Solution found:", current_board)
    else:
        print("\n❌ Solution not found. Best board:", current_board, "Cost:", current_cost)

# Run for 4-Queens starting from [3,1,2,0]
initial_state = [3,1,2,0]
simulated_annealing(4, initial_state)
# Out:
# Initial Board: [3, 1, 2, 0] Cost: 2
#
# Step 0:
# Current Board: [3, 1, 2, 0], Cost: 2
# Neighbor Board: [3, 3, 2, 0], Cost: 3, changed col 1 to row 3
# Move accepted. New board: [3, 3, 2, 0], Cost: 3
#
# Step 1:
# Current Board: [3, 3, 2, 0], Cost: 3
# Neighbor Board: [3, 3, 0, 0], Cost: 3, changed col 2 to row 0
# Move accepted. New board: [3, 3, 0, 0], Cost: 3
#
# Step 2:
# Current Board: [3, 3, 0, 0], Cost: 3
# Neighbor Board: [3, 0, 0, 0], Cost: 4, changed col 1 to row 0
# Move accepted. New board: [3, 0, 0, 0], Cost: 4
#
# Step 3:
# Current Board: [3, 0, 0, 0], Cost: 4
# Neighbor Board: [3, 1, 0, 0], Cost: 3, changed col 1 to row 1
# Move accepted. New board: [3, 1, 0, 0], Cost: 3
#
# Step 4:
# Current Board: [3, 1, 0, 0], Cost: 3
# Neighbor Board: [3, 1, 0, 2], Cost: 1, changed col 3 to row 2
# Move accepted. New board: [3, 1, 0, 2], Cost: 1
#
# Step 5:
# Current Board: [3, 1, 0, 2], Cost: 1
# Neighbor Board: [3, 3, 0, 2], Cost: 1, changed col 1 to row 3
# Move accepted. New board: [3, 3, 0, 2], Cost: 1
#
# Step 6:
# Current Board: [3, 3, 0, 2], Cost: 1
# Neighbor Board: [3, 3, 0, 1], Cost: 3, changed col 3 to row 1
# Move accepted. New board: [3, 3, 0, 1], Cost: 3
#
# Step 7:
# Current Board: [3, 3, 0, 1], Cost: 3
# Neighbor Board: [3, 1, 0, 1], Cost: 3, changed col 1 to row 1
# Move accepted. New board: [3, 1, 0, 1], Cost: 3
#
# Step 8:
# Current Board: [3, 1, 0, 1], Cost: 3
# Neighbor Board: [3, 1, 0, 2], Cost: 1, changed col 3 to row 2
# Move accepted. New board: [3, 1, 0, 2], Cost: 1
#
# Step 9:
# Current Board: [3, 1, 0, 2], Cost: 1
# Neighbor Board: [3, 3, 0, 2], Cost: 1, changed col 1 to row 3
# Move accepted. New board: [3, 3, 0, 2], Cost: 1
#
# Step 10:
# Current Board: [3, 3, 0, 2], Cost: 1
# Neighbor Board: [3, 3, 2, 2], Cost: 3, changed col 2 to row 2
# Move accepted. New board: [3, 3, 2, 2], Cost: 3
#
# Step 11:
# Current Board: [3, 3, 2, 2], Cost: 3
# Neighbor Board: [0, 3, 2, 2], Cost: 3, changed col 0 to row 0
# Move accepted. New board: [0, 3, 2, 2], Cost: 3
#
# Step 12:
# Current Board: [0, 3, 2, 2], Cost: 3
# Neighbor Board: [0, 3, 1, 2], Cost: 1, changed col 2 to row 1
# Move accepted. New board: [0, 3, 1, 2], Cost: 1
#
# Step 13:
# Current Board: [0, 3, 1, 2], Cost: 1
# Neighbor Board: [0, 3, 2, 2], Cost: 3, changed col 2 to row 2
# Move accepted. New board: [0, 3, 2, 2], Cost: 3
#
# Step 14:
# Current Board: [0, 3, 2, 2], Cost: 3
# Neighbor Board: [0, 3, 2, 0], Cost: 3, changed col 3 to row 0
# Move accepted. New board: [0, 3, 2, 0], Cost: 3
#
# Step 15:
# Current Board: [0, 3, 2, 0], Cost: 3
# Neighbor Board: [0, 0, 2, 0], Cost: 4, changed col 1 to row 0
# Move accepted. New board: [0, 0, 2, 0], Cost: 4
#
# Step 16:
# Current Board: [0, 0, 2, 0], Cost: 4
# Neighbor Board: [0, 0, 1, 0], Cost: 5, changed col 2 to row 1
# Move rejected.
#
# Step 17:
# Current Board: [0, 0, 2, 0], Cost: 4
# Neighbor Board: [0, 0, 2, 1], Cost: 3, changed col 3 to row 1
# Move accepted. New board: [0, 0, 2, 1], Cost: 3
#
# Step 18:
# Current Board: [0, 0, 2, 1], Cost: 3
# Neighbor Board: [0, 0, 2, 2], Cost: 4, changed col 3 to row 2
# Move accepted. New board: [0, 0, 2, 2], Cost: 4
#
# Step 19:
# Current Board: [0, 0, 2, 2], Cost: 4
# Neighbor Board: [0, 1, 2, 2], Cost: 4, changed col 1 to row 1
# Move accepted. New board: [0, 1, 2, 2], Cost: 4
#
# Step 20:
# Current Board: [0, 1, 2, 2], Cost: 4
# Neighbor Board: [0, 0, 2, 2], Cost: 4, changed col 1 to row 0
# Move accepted. New board: [0, 0, 2, 2], Cost: 4
#
# Step 21:
# Current Board: [0, 0, 2, 2], Cost: 4
# Neighbor Board: [0, 0, 3, 2], Cost: 3, changed col 2 to row 3
# Move accepted. New board: [0, 0, 3, 2], Cost: 3
#
# Step 22:
# Current Board: [0, 0, 3, 2], Cost: 3
# Neighbor Board: [0, 0, 3, 0], Cost: 3, changed col 3 to row 0
# Move accepted. New board: [0, 0, 3, 0], Cost: 3
#
# Step 23:
# Current Board: [0, 0, 3, 0], Cost: 3
# Neighbor Board: [0, 0, 3, 1], Cost: 1, changed col 3 to row 1
# Move accepted. New board: [0, 0, 3, 1], Cost: 1
#
# Step 24:
# Current Board: [0, 0, 3, 1], Cost: 1
# Neighbor Board: [3, 0, 3, 1], Cost: 1, changed col 0 to row 3
# Move accepted. New board: [3, 0, 3, 1], Cost: 1
#
# Step 25:
# Current Board: [3, 0, 3, 1], Cost: 1
# Neighbor Board: [2, 0, 3, 1], Cost: 0, changed col 0 to row 2
# Move accepted. New board: [2, 0, 3, 1], Cost: 0
#
# ✅ Goal reached! Solution found: [2, 0, 3, 1]
